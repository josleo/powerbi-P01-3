# %%
import pandas as pd
import requests

markets = requests.get('https://ftx.com/api/markets').json()
df = pd.DataFrame(markets['result'])
df.set_index('name', inplace = True)
df.T
# Out:
# name                     1INCH-PERP  1INCH-0930 1INCH-1230    1INCH/USD  \
# enabled                        True        True       True         True
# postOnly                      False       False      False        False
# priceIncrement               0.0001      0.0001     0.0001       0.0001
# sizeIncrement                   1.0         1.0        1.0          1.0
# minProvideSize                  1.0         1.0        1.0          1.0
# last                         0.6232      0.6227     0.6117       0.6233
# bid                          0.6231      0.6177     0.6019       0.6231
# ask                          0.6233      0.6202     0.6046       0.6238
# price                        0.6232      0.6202     0.6046       0.6233
# type                         future      future     future         spot
# futureType                perpetual      future     future         None
# baseCurrency                   None        None       None        1INCH
# ...

# %%
markets = pd.DataFrame(requests.get('https://ftx.com/api/markets/BTC-0924').json())
markets = markets.drop(['success'], axis=1)
markets
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\User\Desktop\repo\P01-3\EDA.ipynb Celda 3 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/repo/P01-3/EDA.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> markets = pd.DataFrame(requests.get('https://ftx.com/api/markets/BTC-0924').json())
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/repo/P01-3/EDA.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> markets = markets.drop(['success'], axis=1)
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/repo/P01-3/EDA.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> markets
#
# File c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:637, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     631     mgr = self._init_mgr(
#     632         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
# ...

# %%
import  datetime
import requests
import pandas as pd
from datetime import datetime

# %%
import time
import hmac
from requests import Request

ts = int(time.time() * 1000)
request = Request('GET', 'https://ftx.com/api')
prepared = request.prepare()
signature_payload = f'{ts}{prepared.method}{prepared.path_url}'.encode()
signature = hmac.new('BLugSqHutljX8gTZQZkSacuF-Ygo8L1JpHZoFWtc'.encode(), signature_payload, 'sha256').hexdigest()

prepared.headers['FTX-KEY'] = 'YOUR_API_KEY'
prepared.headers['FTX-SIGN'] = signature
prepared.headers['FTX-TS'] = str(ts)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\User\Desktop\repo\P01-3\EDA.ipynb Celda 3 in <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/repo/P01-3/EDA.ipynb#X20sZmlsZQ%3D%3D?line=9'>10</a> all_markets = requests.get(endpoint_url).json()
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/repo/P01-3/EDA.ipynb#X20sZmlsZQ%3D%3D?line=11'>12</a> # Convert JSON to Pandas DataFrame
# ---> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/repo/P01-3/EDA.ipynb#X20sZmlsZQ%3D%3D?line=12'>13</a> df = pd.DataFrame(all_markets['result'])
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/repo/P01-3/EDA.ipynb#X20sZmlsZQ%3D%3D?line=13'>14</a> df.set_index('name', inplace = True)
# ...

# %%
import  datetime
import requests
import pandas as pd
from datetime import datetime
endpoint_url = 'https://ftx.com/api/markets'

# Get all market data as JSON
all_markets = requests.get(endpoint_url).json()

# Convert JSON to Pandas DataFrame
df = pd.DataFrame(all_markets['result'])
df.set_index('name', inplace = True)
df. reset_index (drop = False , inplace = True )
#a = df["name"]=="BNB/USD"

a = df["name"]=="ETHE/USD" 
#BTC/USD
#ETH/USD
# USDT/USD	

# BNB/USD
# XRP/USD
#######BUSD/USD	 
#aADA
b= df.name.str.match("DAI/USD.*") 
planets_2008 = df[b]
planets_2008

#""datos = df[df.name.isin(["BTC/USD", "ETH/USD","USDT/USD","BNB/USD","XRP/USD"])]
#datos
# Out:
#          name  enabled  postOnly  priceIncrement  sizeIncrement  \
# 220   DAI/USD     True     False          0.0001            0.1
# 221  DAI/USDT     True     False          0.0001            0.1
#
#      minProvideSize  last     bid     ask  price  ... highLeverageFeeExempt  \
# 220             0.1   1.0  0.9996  1.0000    1.0  ...                  True
# 221             0.1   1.0  1.0000  1.0001    1.0  ...                  True
#
#     largeOrderThreshold change1h  change24h changeBod quoteVolume24h  \
# 220               280.0      0.0     0.0002       0.0   291544.96827
# 221               196.0      0.0     0.0000       0.0    11994.21935
#
#       volumeUsd24h  priceHigh24h  priceLow24h  tokenizedEquity
# 220  291544.968270        1.0000       0.9996              NaN
# 221   11993.819583        1.0005       0.9997              NaN
#
# [2 rows x 27 columns]

# %%
import seaborn as sbññ
df[df.method.str.contains('BNK?', regex=True)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\User\Desktop\repo\P01-3\EDA.ipynb Celda 4 in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/repo/P01-3/EDA.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> import seaborn as sb
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/repo/P01-3/EDA.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> df[df.method.str.contains('BNK?', regex=True)]
#
# File c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:5583, in NDFrame.__getattr__(self, name)
#    5576 if (
#    5577     name not in self._internal_names_set
#    5578     and name not in self._metadata
#    5579     and name not in self._accessors
#    5580     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5581 ):
#    5582     return self[name]
# -> 5583 return object.__getattribute__(self, name)
#
# ...

# %%
foo = pd. DataFrame({"a" : [1,2,3,4], "b" : ["hola", "foo", "gordo", "gato"]})
foo.b.str.match("f.*")
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# Name: b, dtype: bool

# %%
foo.b.str.match( "(f.*)").str.len() > 0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\User\Desktop\repo\P01-3\EDA.ipynb Celda 6 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/repo/P01-3/EDA.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> foo.b.str.match( "(f.*)").str.len() > 0
#
# File c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:5583, in NDFrame.__getattr__(self, name)
#    5576 if (
#    5577     name not in self._internal_names_set
#    5578     and name not in self._metadata
#    5579     and name not in self._accessors
#    5580     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5581 ):
#    5582     return self[name]
# -> 5583 return object.__getattribute__(self, name)
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\User\Desktop\repo\P01-3\EDA.ipynb Celda 5 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/repo/P01-3/EDA.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> df[df.method.str.contains('BNK?', regex=True)]
#
# File c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:5583, in NDFrame.__getattr__(self, name)
#    5576 if (
#    5577     name not in self._internal_names_set
#    5578     and name not in self._metadata
#    5579     and name not in self._accessors
#    5580     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5581 ):
#    5582     return self[name]
# -> 5583 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'method'

# %%
df['name']=='specific_value'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# ...

# %%
base_currency = 'BTC'
quote_currency = 'USD'
# Specify the base and quote currencies to get single market data
request_url = f'{endpoint_url}/{base_currency}/{quote_currency}'
df = pd.DataFrame(requests.get(request_url).json())
df['result']
# Out:
# ask                             19093.0
# baseCurrency                        BTC
# bid                             19092.0
# change1h                       0.000314
# change24h                      0.000105
# changeBod                      0.016829
# enabled                            True
# futureType                         None
# highLeverageFeeExempt              True
# isEtfMarket                       False
# largeOrderThreshold              2400.0
# last                            19093.0
# minProvideSize                   0.0001
# name                            BTC/USD
# postOnly                          False
# price                           19093.0
# priceHigh24h                    19318.0
# priceIncrement                      1.0
# priceLow24h                     18633.0
# quoteCurrency                       USD
# quoteVolume24h           625677273.4624
# restricted                        False
# sizeIncrement                    0.0001
# ...

# %%
import  datetime
import requests
import pandas as pd
from datetime import datetime

base_currency = 'BTC'
quote_currency = 'USD'
# Specify the base and quote currencies to get single market data
request_url = f'{endpoint_url}/{base_currency}/{quote_currency}'



endpoint_url = 'https://ftx.com/api/markets'

# Get all market data as JSON
all_markets = requests.get(endpoint_url).json()

# Convert JSON to Pandas DataFrame
df = pd.DataFrame(all_markets['result'])
df.set_index('name', inplace = True)
df. reset_index (drop = False , inplace = True )

# 1 day = 60 * 60 * 24 seconds
daily=str(60*60*24)
# Start date = 2021-01-01
start_date = datetime(2021, 1, 1).timestamp()
# Get the historical market data as JSON
historical = requests.get(f'{request_url}/candles?resolution={daily}&start_time={start_date}').json()
# Convert JSON to Pandas DataFrame
df = pd.DataFrame(historical['result'])
# Convert time to date
df['date'] = pd.to_datetime(df['time']/1000, unit='s', origin='unix') 
# Remove unnecessar columns
df.drop(['startTime', 'time'], axis=1, inplace=True)
df
# Out:
#         open     high      low    close        volume       date
# 0    28965.0  29691.5  28700.0  29399.0  1.721861e+08 2021-01-01
# 1    29399.0  33349.5  29023.5  32201.5  2.544018e+08 2021-01-02
# 2    32201.5  34809.5  31978.0  33045.5  1.470195e+08 2021-01-03
# 3    33045.5  33658.5  27700.5  32005.0  1.782005e+08 2021-01-04
# 4    32005.0  34499.5  29923.5  34034.5  1.324108e+08 2021-01-05
# ..       ...      ...      ...      ...           ...        ...
# 630  19401.0  19493.0  18531.0  19288.0  5.846532e+08 2022-09-23
# 631  19288.0  19310.0  18809.0  18922.0  2.964388e+08 2022-09-24
# 632  18922.0  19188.0  18632.0  18809.0  2.248359e+08 2022-09-25
# 633  18809.0  19318.0  18687.0  19228.0  7.497010e+08 2022-09-26
# 634  19228.0  20387.0  19192.0  20184.0  6.139141e+08 2022-09-27
#
# [635 rows x 6 columns]

# %%
fig = go.Figure()
fig.update_layout(
    title={
        'text': f"{base_currency}/{quote_currency}",
        'x':0.5,
        'xanchor': 'center'
    },
    xaxis_title="Date",
    yaxis_title="Price",
    xaxis_rangeslider_visible=False
)
fig.add_trace(
    go.Candlestick(
        x=df['date'],
        open=df['open'],
        high=df['high'],
        low=df['low'],
        close=df['close']
    )
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\User\Desktop\repo\P01-3\EDA.ipynb Celda 7 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/repo/P01-3/EDA.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> fig = go.Figure()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/repo/P01-3/EDA.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> fig.update_layout(
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/repo/P01-3/EDA.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>     title={
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/repo/P01-3/EDA.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>         'text': f"{base_currency}/{quote_currency}",
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/repo/P01-3/EDA.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a>     xaxis_rangeslider_visible=False
# ...
